# %% [markdown]
# # torch和torchvision

# %% [markdown]
# 导入必要的包

# %%
import torch
import torchvision
from torchvision import datasets, transforms
from torch.autograd import Variable
from torchvision.transforms import ToPILImage
import matplotlib.pyplot as plt

# %% [markdown]
# # PyTorch 之torch.transforms

# %% [markdown]
# 对数据载入及有相应变化

# %%
transform=transforms.Compose([transforms.ToTensor(),
                             transforms.Normalize(mean=[0.5,0.5,0.5],std=[0.5,0.5,0.5])])

# %% [markdown]
# 获取训练集和测试集

# %%
data_train = datasets.MNIST(root="F:\\python_study\\MNIST\\",
                           transform=transform,
                           train=True,
                           download = True)
data_test = datasets.MNIST(root="F:\\python_study\\MNIST\\",
                          transform=transform,
                          train=False)

# %% [markdown]
# # 数据预览和数据装载

# %% [markdown]
# 在装载时通过batch_size的值确认每个包的大小，通过shuffle的值来确认是否在装载的过程中打乱图片的顺序

# %%
data_loader_train = torch.utils.data.DataLoader(dataset=data_train,
                                             batch_size=64,
                                             shuffle=True)
data_loader_test = torch.utils.data.DataLoader(dataset=data_test,
                                            batch_size=64,
                                            shuffle=True)

# %% [markdown]
# 数据预览

# %%
images, labels =next(iter(data_loader_train)) 
img = torchvision.utils.make_grid(images)
img = img.numpy().transpose(1,2,0)
std=[0.5,0.5,0.5]
mean=[0.5,0.5,0.5]
img=img*std+mean
print([labels[i] for i in range(64)])
plt.imshow(img)
# Out:
# [tensor(2), tensor(9), tensor(3), tensor(5), tensor(3), tensor(2), tensor(9), tensor(3), tensor(7), tensor(8), tensor(7), tensor(5), tensor(9), tensor(8), tensor(4), tensor(8), tensor(2), tensor(6), tensor(5), tensor(9), tensor(4), tensor(7), tensor(3), tensor(9), tensor(3), tensor(6), tensor(9), tensor(8), tensor(5), tensor(7), tensor(6), tensor(5), tensor(7), tensor(1), tensor(3), tensor(4), tensor(2), tensor(4), tensor(0), tensor(3), tensor(5), tensor(0), tensor(8), tensor(1), tensor(2), tensor(2), tensor(0), tensor(4), tensor(6), tensor(2), tensor(1), tensor(2), tensor(4), tensor(5), tensor(6), tensor(8), tensor(1), tensor(2), tensor(6), tensor(7), tensor(7), tensor(2), tensor(6), tensor(2)]

# %% [markdown]
# # 搭建模型和参数优化

# %% [markdown]
# 实现卷积神经网络模型

# %%
class Model(torch.nn.Module):
    
    def __init__(self):
        super(Model, self).__init__()
        self.conv1=torch.nn.Sequential(
        torch.nn.Conv2d(1,64,kernel_size=3,stride=1,padding=1),
        torch.nn.ReLU(),
        torch.nn.Conv2d(64,128,kernel_size=3,stride=1,padding=1),
        torch.nn.ReLU(),
        torch.nn.MaxPool2d(stride=2,kernel_size=2))
        
        self.dense=torch.nn.Sequential(
        torch.nn.Linear(14*14*128,1024),
        torch.nn.ReLU(),
        torch.nn.Dropout(p=0.5),
        torch.nn.Linear(1024,10))
        
    def forward(self, x):
        x=self.conv1(x)
        x=x.view(-1,14*14*128)
        x=self.dense(x)
        return x

# %%
model=Model()
cost=torch.nn.CrossEntropyLoss()
optimizer=torch.optim.Adam(model.parameters())

# %%
print(model)
# Out:
# Model(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=25088, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
